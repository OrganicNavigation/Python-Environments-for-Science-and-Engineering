# %% [markdown]
# # Python Environments for Science and Engineering
#
# Hamid Mokhtarzadeh
#
# *hamid@organicnavigation.com*
# ![](img/organic-navigation-header-sm.png)
#
# ## Using Python
#
# * Parsing and visualizing sensor data
#     - *e.g. acclerometer, gyro, magnetometer, bluetooth, gps, camera...*
# * Prototyping algorithms
# * Understanding the work of others
#     - *e.g. PX4 autopilot toolchain*

# %% [markdown]
# # Two Objective
#
# 1. Understand setups available
# 2. Collective feedback on utility of each

# %% [markdown]
# <img src="img/software-vs-algorithm-complexity.png" style="height: 500px;"/>

# %%
% matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_context("notebook", font_scale=2.0)
df = pd.DataFrame.from_csv('python-feedback.txt')
f = plt.figure(figsize=(12,6))
sns.heatmap(np.log(df), annot=True)
f.savefig("img/python-feedback-results.png")

# %% [markdown]
# ## Terminal and Editor
#
# <img src="img/terminal-editor.png" style="width: 400px;"/>

# %% [markdown]
# **Terminals:** [Python.org](http://python.org/) | [IPython](http://ipython.org/)
#
# **Editors:** [Notepad++](https://notepad-plus-plus.org) | [Sublime Text](http://sublimetext.com/)

# %% [markdown]
# ## Software IDE (Integrated Development Environment)
#
# <img src="img/software-ide.png" style="width: 400px;"/>

# %% [markdown]
# [Eclipse](https://eclipse.org/) + [PyDev](http://www.pydev.org/) | [PyCharm](https://www.jetbrains.com/pycharm/)

# %% [markdown]
# ## Algorithm IDE
#
# <img src="img/algorithm-ide.png" style="width: 400px;"/>

# %% [markdown]
# [Spyder](http://www.spyder-ide.org/) | [Rodeo](https://www.yhat.com/products/rodeo) | [Enthought Canopy](https://www.enthought.com/products/canopy/features/)

# %% [markdown]
# ## Notebook
#
# <img src="img/notebook.png" style="width: 400px;"/>

# %% [markdown]
# [Jupyter Notebook](http://jupyter.org/) | [Zepplin](https://zeppelin.apache.org/) | *Others? Watch this space!*

# %% [markdown]
# ## Feedback Results
#
# ![](img/python-feedback-results.png)

# %% [markdown]
# ## Summary & Discussion
#
#
# <img src="img/software-vs-algorithm-complexity.png" style="height: 500px;"/>
#
# *Thanks!*
#
# `hamid@organicnavigation.com`
